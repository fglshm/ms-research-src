# %%
import pandas as pd

so_nso_sentence_stats = pd.read_csv("all_sentence_stats.csv")
so_nso_sentence_stats.sort_values(by=['title'])
# Out:
#                 title  standing ovation    mean  median  variance  \
# 0                mean                 0   17.04   16.60     11.82
# 5                mean                 1   16.23   16.00     11.43
# 1              median                 0   14.54   14.00     11.39
# 6              median                 1   13.65   13.00     10.75
# 4      sentence count                 0  120.93  114.00   2814.64
# 9      sentence count                 1  147.83  140.00   3761.83
# 3  standard deviation                 0   11.33   10.91      8.18
# 8  standard deviation                 1   11.21   10.70      8.45
# 2            variance                 0  136.44  119.11   5845.27
# 7            variance                 1  134.06  114.42   6006.59
#
#    standard deviation
# 0                3.44
# 5                3.38
# 1                3.38
# 6                3.28
# 4               53.05
# 9               61.33
# 3                2.86
# 8                2.91
# 2               76.45
# ...

# %%
"""
上の表は, so/nso それぞれのスピーチの, 1 文あたりの単語数の平均, 単語数の中央値, 単語数の分散, 単語数の標準偏差の, 平均, 中央値, 分散, 標準偏差の値である.
この表データから分かることは, 1 文あたりの単語数の平均, 中央値, 分散, 標準偏差において, so/nso でそこまで違いは見られないということ.
文章数で so が多いのは, so のスピーチの方がスピーチ時間が長いから.
ただ, 今着目した点は, スピーチにおける 1 文章同士の関係性であるため, この値で違いが見られなくても気にすることはない.
上のグラフは 1 文同士の関係性を測る指標ではない.
"""
# Out:
# '\n上の表は, so/nso それぞれのスピーチの, 1 文あたりの単語数の平均, 単語数の中央値, 単語数の分散, 単語数の標準偏差の, 平均, 中央値, 分散, 標準偏差の値である.\nこの表データから分かることは, 1 文あたりの単語数の平均, 中央値, 分散, 標準偏差において, so/nso でそこまで違いは見られないということ.\n文章数で so が多いのは, so のスピーチの方がスピーチ時間が長いから.\nただ, 今着目した点は, スピーチにおける 1 文章同士の関係性であるため, この値で違いが見られなくても気にすることはない.\n上のグラフは 1 文同士の関係性を測る指標ではない.\n'

# %%
so_sentence_stats = pd.read_csv('so_sentence_stats.csv')
so_sentence_stats
# Out:
#        id  standing ovation   mean  median  variance  standard deviation  \
# 0    1735                 1  18.38    17.0    146.98               12.12
# 1    3122                 1  13.26    10.0    119.64               10.94
# 2    2228                 1  20.78    17.0    234.40               15.31
# 3     504                 1  15.42    14.0     95.32                9.76
# 4    3693                 1  13.87    11.0     87.77                9.37
# 5    1084                 1  10.78     9.0     55.42                7.44
# 6    2764                 1  15.00    14.0     80.34                8.96
# 7     921                 1  14.16    11.0    153.22               12.38
# 8     935                 1  12.68    10.5     77.83                8.82
# 9     706                 1  16.53    14.0    127.89               11.31
# 10   2176                 1  19.10    17.0    149.13               12.21
# 11   2610                 1  15.53    13.0    127.01               11.27
# ...

# %%
nso_sentence_stats = pd.read_csv('nso_sentence_stats.csv')
nso_sentence_stats
# Out:
#        id  standing ovation   mean  median  variance  standard deviation  \
# 0    1053                 0  15.33    13.5     82.38                9.08
# 1    2200                 0  23.61    18.0    305.53               17.48
# 2     289                 0  13.58    11.5     74.17                8.61
# 3    1090                 0  16.13    12.0    127.34               11.28
# 4    3687                 0  12.52    12.0     51.86                7.20
# 5    1912                 0  24.43    24.0    257.13               16.04
# 6    2994                 0  14.31    12.0    117.25               10.83
# 7    3334                 0  24.57    24.0    141.29               11.89
# 8    1292                 0  16.96    15.0     99.92               10.00
# 9     712                 0  16.86    15.0     79.38                8.91
# 10   1286                 0  28.21    24.0    331.88               18.22
# 11   3526                 0  16.52    11.0    169.59               13.02
# ...
