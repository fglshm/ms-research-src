# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import interpolate

speech_type = 'so'

so_results = np.load(f"{speech_type}_similarities.npy")

x = np.array(so_results[236])
print(x)
y = np.arange(x.shape[0])
color = "blue" if speech_type == 'so' else 'red'
plt.xlabel("sentence")
plt.ylabel("non-similarity")
plt.plot(y, x, color=color)
figure = plt.gcf()
figure.set_size_inches(20, 10)
plt.show()
# Out:
# [ 0.    4.    7.08  0.24  1.05  1.    2.    0.21  0.56  1.4   3.57  0.8
#   1.3   0.15  1.5   6.33  0.74  0.14  0.75  2.    0.83  1.    0.8  11.
#   0.18  2.5   0.15  2.    3.    0.22  1.25  0.8   1.5   2.83  0.59  0.9
#   3.    1.19  0.16  6.2   1.39  0.56  1.58  0.76  1.31  0.63  0.58  1.71
#   0.58  0.71  2.4   0.62  0.67  1.2   1.83  0.55  0.42  1.6   0.88  1.
#   0.71  1.2   2.83  0.18  1.    3.    0.44  1.5   3.5   0.62  0.69  0.56
#   0.8   1.25  2.6   0.54  2.71  0.68  1.    0.54  1.14  2.25  0.89  0.38
#   2.5   0.27  2.25  0.67  1.67  1.8   0.44  0.62  2.2   0.45  0.6   5.
#   0.67  1.    1.4   0.79  1.    1.    0.36  9.25  0.86  1.28  0.24  1.1
#   2.82  1.23  0.26  1.    2.3   1.    0.48  1.82  0.75  1.67  0.6   1.93
#   0.62  0.83  0.33  1.   16.4   0.35  0.28]

# %%
# signal = np.sin(2*np.pi*x/x.shape[0])
# F = np.fft.fft(signal)
# F_abs = np.abs(F)
# figure = plt.gcf()
# figure.set_size_inches(20, 10)
# plt.plot(F_abs)

# %%
# a = [2.0, 1.2, 0.2, 1.3, 2.3, 1.7, 0.9]
# np_a = np.array(a)
# F = np.fft.fft(np_a)
# Amp = np.abs(F)
# Pow = Amp ** 2
# plt.plot(freq, Pow, label='|F(k)|')

F = np.fft.fft(x)
figure = plt.gcf()
figure.set_size_inches(20, 10)
plt.plot(F)
