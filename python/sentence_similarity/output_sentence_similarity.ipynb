# %%
import sys
sys.path.append('..')
import similarity

# %%
simi = similarity.word_count_similarity('/Users/shohei/Tsukuba/tsukuba/research/master/src/others/ted/transcript', 'so', '2265')

# %%
simi
# Out:
# [0.0,
#  9.75,
#  0.31,
#  2.58,
#  0.58,
#  0.61,
#  2.91,
#  0.78,
#  1.04,
#  0.5,
#  0.54,
#  0.86,
#  3.0,
#  2.06,
#  0.3,
#  0.73,
#  1.88,
#  0.67,
#  0.5,
#  5.0,
#  0.64,
#  2.25,
#  0.28,
#  1.9,
#  1.53,
#  0.59,
#  0.24,
#  0.5,
#  12.0,
#  0.96,
#  0.91,
#  0.86,
#  1.5,
#  0.89,
#  0.25,
#  5.0,
#  0.3,
#  1.44,
#  1.62,
#  1.86,
#  0.62,
#  1.0,
#  1.17,
#  0.86,
#  1.92,
#  0.24,
#  2.27,
#  0.68,
#  1.82,
#  0.58,
#  2.0,
#  0.17,
#  0.5,
#  11.67,
#  1.09,
#  0.42,
#  1.06,
#  2.0,
#  0.44,
#  1.0,
#  2.07,
#  0.61,
#  0.74,
#  2.64,
#  0.62,
#  0.57,
#  1.54,
#  0.6,
#  2.58,
#  0.48,
#  2.33,
#  0.34,
#  1.58,
#  0.37,
#  2.86,
#  1.3,
#  1.23,
#  0.31,
#  3.9,
#  0.26,
#  2.1,
#  0.81,
#  1.0,
#  2.06,
#  0.23,
#  0.62,
#  4.0,
#  0.9,
#  0.44,
#  2.62,
#  0.67,
#  1.71,
#  1.17,
#  0.75,
#  0.57,
#  0.83,
#  1.9,
#  1.21,
#  0.52,
#  1.83,
#  0.91,
#  1.1,
#  0.64,
#  0.5,
#  6.86,
#  0.6,
#  1.14,
#  0.18,
#  2.0,
#  0.5,
#  0.67]
